# %%
import pandas as pd
import numpy as np

# %%
kgg = pd.read_csv('kg_grouped.csv')
kgg[kgg.x_type == 'disease']
# Out:
# /tmp/ipykernel_344/850632400.py:1: DtypeWarning: Columns (2,6) have mixed types. Specify dtype option on import or set low_memory=False.
#   kgg = pd.read_csv('kg_grouped.csv')
#                            relation  display_relation  \
# 3258080  disease_phenotype_negative  phenotype absent
# 3258081  disease_phenotype_negative  phenotype absent
# 3258082  disease_phenotype_negative  phenotype absent
# 3258083  disease_phenotype_negative  phenotype absent
# 3258084  disease_phenotype_negative  phenotype absent
# ...                             ...               ...
# 9034186            exposure_disease         linked to
# 9034187            exposure_disease         linked to
# 9034188            exposure_disease         linked to
# 9034189            exposure_disease         linked to
# 9034190            exposure_disease         linked to
#
#                                                       x_id   x_type  \
# 3258080  12204_10435_8024_30105_14348_10604_10215_11568...  disease
# ...

# %%
kgd = pd.read_csv('kg_grouped_diseases.csv')
kgd
# Out:
#        Unnamed: 0  node_id node_type  \
# 0               0    12204   disease
# 1               1     7217   disease
# 2               2    10435   disease
# 3               3     7764   disease
# 4               4    10541   disease
# ...           ...      ...       ...
# 23333       23333  8000019   disease
# 23334       23334  8000023   disease
# 23335       23335     1306   disease
# 23336       23336      839   disease
# 23337       23337     5902   disease
#
#                                             node_name node_source  \
# 0                         familial pseudohyperkalemia       MONDO
# 1                               brachydactyly type A3       MONDO
# 2                   nystagmus 6, congenital, X-linked       MONDO
# 3       autosomal dominant osteosclerosis, Worth type       MONDO
# 4                     X-linked calvarial hyperostosis       MONDO
# ...                                               ...         ...
# ...

# %%
len(kgd.group_name_bert.unique()), len(kgd.group_name_auto.unique())
# Out:
# (16509, 19370)

# %%
kgold = pd.read_csv('old/kg_grouped_diseases.csv')
kgold
# Out:
#        node_id node_type                                          node_name  \
# 0        13924   disease                    osteogenesis imperfecta type 13
# 1        11160   disease       autosomal recessive nonsyndromic deafness 15
# 2         8099   disease  congenital stationary night blindness autosoma...
# 3        14854   disease        autosomal dominant nonsyndromic deafness 66
# 4        33202   disease                  deafness, autosomal recessive 109
# ...        ...       ...                                                ...
# 22200   400000   disease              small intestinal bacterial overgrowth
# 22201   400002   disease                            calcium-alkali syndrome
# 22202   400003   disease                                 skeletal fluorosis
# 22203   400004   disease                                        phrynoderma
# 22204   400005   disease                                 refeeding syndrome
#
# ...

# %%
len(kgold.group_name_bert.unique()), len(kgold.group_name_auto.unique())
# Out:
# (17080, 18633)

# %%
19370 / 18633
# Out:
# 1.0395534803842645
